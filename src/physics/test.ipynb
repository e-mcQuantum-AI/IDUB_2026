# %%
from generate import State_Database_Generator

from state.fock import FockState 
from state.cat import CatState
from state.thermal import ThermalState
from state.coherent import CoherentState
from state.binomal import BinomialState
from state.gkp import GKPState 
from state.vacuum import VacuumState

# %%
Generator = State_Database_Generator(cutoff=20, N=10, root_dir="./data/")

# %%
# FockState CatState ThermalState CoherentState BinomialState GKPState VacuumState 
Generator.generate(CatState, "Cat", alpha=1)
# Out:
# Generujemy 10 plikuw...
